# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir('D:/USF MS BAIS CourseWork/Sem-2/Data Visualization/DataAnalysisWithPythonCookbook-master/datasets')

# %%
df=pd.read_csv("gradedata.csv")

# %%
# random 500 rows
df.take(np.random.permutation(len(df))[:500])
# Out:
#         fname      lname  gender  age  exercise  hours  grade  \
# 501        Bo    Miranda  female   18         1     11   82.8
# 1467   Juliet     Golden  female   16         4     14   85.5
# 1424  Gregory      Myers    male   15         1     12   77.5
# 1051   Lucius       Vang    male   15         3     10   80.6
# 1259    Kiona  Hernandez  female   14         2      9   84.3
# ...       ...        ...     ...  ...       ...    ...    ...
# 279     Elvis    Watkins    male   14         2     11   80.7
# 1036    Jacob    Lindsey    male   16         4     11   88.1
# 1448     Beck  Mcconnell    male   15         2     10   80.1
# 264      Noah       Cote    male   14         2     13   84.3
# 1003    Basil    Gilbert    male   14         4     10   78.1
#
#                                               address
# 501               7982 Lakeview St., Reston, VA 20191
# 1467          983 Rockledge Ave., Whitehall, PA 18052
# 1424       18 Peninsula Street, Grand Forks, ND 58201
# 1051  8502 East Lancaster Rd., Crystal Lake, IL 60014
# 1259        439 Greenview St., Newport News, VA 23601
# ...                                               ...
# 279               8885 10th Ave., Rock Hill, SC 29730
# 1036        35 Old Young Court, Garden City, NY 11530
# 1448              256 Elmwood Lane, Buckeye, AZ 85326
# 264    885 Mountainview Rd., Roanoke Rapids, NC 27870
# 1003        757 Jockey Hollow Drive, Pelham, AL 35124
#
# [500 rows x 8 columns]
